# %%
# importing libraries
import sklearn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading processed data
automobile_df = pd.read_csv('datasets/auto-mgp-processed.csv')
automobile_df.sample(5)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  age
# 352  18.0          6         258.0         110    2962          13.5   48
# 158  33.5          4         151.0          90    2556          13.2   40
# 236  29.0          4         135.0          84    2525          16.0   37
# 5    23.9          8         260.0          90    3420          22.2   40
# 258  15.0          8         400.0         150    3761           9.5   49

# %%
# creating data for training based on single feature
X = automobile_df[['horsepower']]
Y = automobile_df['mpg']

# %%
# spliting data into test and train data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
# training and fitting data
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression(normalize=True).fit(x_train, y_train)

# %%
# printing training score
print('Training Score :', linear_model.score(x_train, y_train))
# Out:
# Training Score : 0.6025349852899939

# %%
# predicting values
y_pred = linear_model.predict(x_test)

# %%
# calculating r2 for model
from sklearn.metrics import r2_score
print('R Score :', r2_score(y_test, y_pred))
# Out:
# R Score : 0.6155647997186877

# %%
# visualizing prediction
fig, ax = plt.subplots(figsize=(12,8))
plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, color='r')
plt.xlabel('Horsepower')
plt.ylabel('Miles Per Gallons')
plt.show()

# %%
# line map
plt.figure(figsize=(20,10))
plt.plot(y_pred, label='Predicted')
plt.plot(y_test.values, label='Actual')
plt.ylabel('Mpg')
plt.legend()
plt.show()

# %%
# creating data for training based on single feature
X = automobile_df[['age']]
Y = automobile_df['mpg']

# %%
# spliting data into test and train data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
# training and fitting data
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression(normalize=True).fit(x_train, y_train)

# %%
# printing training score
print('Training Score :', linear_model.score(x_train, y_train))
# Out:
# Training Score : 0.3488920075927102

# %%
# predicting values
y_pred = linear_model.predict(x_test)

# %%
# calculating r2 for model
from sklearn.metrics import r2_score
print('R Score :', r2_score(y_test, y_pred))
# Out:
# R Score : 0.2445390068333051

# %%
# visualizing prediction
fig, ax = plt.subplots(figsize=(12,8))
plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, color='r')
plt.xlabel('Age')
plt.ylabel('Miles Per Gallons')
plt.show()

# %%
# line map
plt.figure(figsize=(20,10))
plt.plot(y_pred, label='Predicted')
plt.plot(y_test.values, label='Actual')
plt.ylabel('Mpg')
plt.legend()
plt.show()

# %%
# creating data for training based on single feature
X = automobile_df[['weight']]
Y = automobile_df['mpg']

# %%
# spliting data into test and train data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
# training and fitting data
from sklearn.linear_model import LinearRegression
linear_model = LinearRegression(normalize=True).fit(x_train, y_train)

# %%
# printing training score
print('Training Score :', linear_model.score(x_train, y_train))
# Out:
# Training Score : 0.6824261121600186

# %%
# predicting values
y_pred = linear_model.predict(x_test)

# %%
# calculating r2 for model
from sklearn.metrics import r2_score
print('R Score :', r2_score(y_test, y_pred))
# Out:
# R Score : 0.7326298229205381

# %%
# visualizing prediction
fig, ax = plt.subplots(figsize=(12,8))
plt.scatter(x_test, y_test)
plt.plot(x_test, y_pred, color='r')
plt.xlabel('Age')
plt.ylabel('Miles Per Gallons')
plt.show()

# %%
# line map
plt.figure(figsize=(20,10))
plt.plot(y_pred, label='Predicted')
plt.plot(y_test.values, label='Actual')
plt.ylabel('Mpg')
plt.legend()
plt.show()
